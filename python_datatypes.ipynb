# %% [markdown]
# 1.Add 2 numbers

# %%
a=10
b=22
print(a+b)
# Out:
# 32

# %% [markdown]
# 2.Print Name

# %%
a="sameea"
print(a)
# Out:
# sameea

# %%
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-85111a3ab660> in <cell line: 1>()
# ----> 1 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
c="O P"
print(a+c)
# Out:
# sameeaO P

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
a=input()
b=input()
print(a+b)
# Out:
# 1
# 3
# 13

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print(type(b))
# Out:
# <class 'str'>

# %%
a=int(input())
b=int(input())
print(a+b)
# Out:
# 1
# 3
# 4

# %%
a=int(input("enter your first value:"))
b=int(input("enter your second value:"))
print(a+b)
# Out:
# enter your first value:24
# enter your second value:8
# 32

# %% [markdown]
# string

# %%
a="sameea"
print(len(a))
# Out:
# 6

# %%
str1="helloWorldhowareyouiamfine"
str1.capitalize()
# Out:
# 'Helloworldhowareyouiamfine'

# %%
str2="hello world how are you"
str2.title()
# Out:
# 'Hello World How Are You'

# %%
str2.upper()
# Out:
# 'HELLO WORLD HOW ARE YOU'

# %%
str2.lower()
# Out:
# 'hello world how are you'

# %%
str1="hello World how are you iam fine"
str1.capitalize()
# Out:
# 'Hello world how are you iam fine'

# %%
str2.count("hello ")
# Out:
# 1

# %%
str2.find("you")
# Out:
# 20
